# %% [markdown]
# # Lab6.4-Topic-classification-BERT

# %% [markdown]
# Copyright: Vrije Universiteit Amsterdam, Faculty of Humanities, CLTL

# %% [markdown]
# In this notebook, we demonstrate how to fine-tune BERT for topic classification.
#
# We will use the [simpletransformers library](https://simpletransformers.ai/):
#  wrapper for the [huggingface transformers library](https://huggingface.co/) on PyTorch.

# %% [markdown]
# We are going to run the notebook on [colab](https://colab.research.google.com/?utm_source=scs-index), which has (limited) free access to GPUs.
#
# You need to enable GPUs for the notebook:
#
# * navigate to Edit → Notebook Settings
# * select GPU from the Hardware Accelerator drop-down

# %% [markdown]
# ### Install/import libraries

# %% [markdown]
# Install the simpletransformers library (restart your runtime after the installation)

# %%
##!pip install simpletransformers
# Out:
# Collecting simpletransformers
#   Downloading simpletransformers-0.70.5-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from simpletransformers) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from simpletransformers) (2.32.4)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.12/dist-packages (from simpletransformers) (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from simpletransformers) (2025.11.3)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.12/dist-packages (from simpletransformers) (5.0.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from simpletransformers) (4.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from simpletransformers) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from simpletransformers) (1.6.1)
# Collecting seqeval (from simpletransformers)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from simpletransformers) (2.20.0)
# Collecting tensorboardx (from simpletransformers)
#   Downloading tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from simpletransformers) (2.2.2)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from simpletransformers) (0.22.2)
# Requirement already satisfied: wandb>=0.10.32 in /usr/local/lib/python3.12/dist-packages (from simpletransformers) (0.26.1)
# Collecting streamlit (from simpletransformers)
#   Downloading streamlit-1.57.0-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from simpletransformers) (0.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers>=4.31.0->simpletransformers) (3.29.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.31.0->simpletransformers) (1.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.31.0->simpletransformers) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.31.0->simpletransformers) (6.0.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.31.0->simpletransformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.31.0->simpletransformers) (0.7.0)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers) (8.3.3)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers) (3.1.47)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers) (4.9.6)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers) (5.29.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers) (2.12.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers) (2.58.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->simpletransformers) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->simpletransformers) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->simpletransformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->simpletransformers) (2026.4.22)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->simpletransformers) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->simpletransformers) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->simpletransformers) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->simpletransformers) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers) (2025.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->simpletransformers) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->simpletransformers) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->simpletransformers) (2026.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->simpletransformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->simpletransformers) (3.6.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (6.2.6)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (11.3.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->simpletransformers)
#   Downloading pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: starlette>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (0.52.1)
# Requirement already satisfied: uvicorn>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (0.46.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (0.7.1)
# Requirement already satisfied: anyio>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (4.13.0)
# Requirement already satisfied: python-multipart>=0.0.10 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (0.0.26)
# Requirement already satisfied: websockets>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (15.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers) (6.0.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->simpletransformers) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->simpletransformers) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->simpletransformers) (3.10.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->simpletransformers) (75.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->simpletransformers) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->simpletransformers) (3.1.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers) (2.20.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers) (3.13.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.31.0->simpletransformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.31.0->simpletransformers) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.31.0->simpletransformers) (0.24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.10.32->simpletransformers) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.10.32->simpletransformers) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.10.32->simpletransformers) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->simpletransformers) (1.17.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.30.0->streamlit->simpletransformers) (0.16.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers) (1.23.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers) (5.0.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.31.0->simpletransformers) (1.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers) (0.30.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.31.0->simpletransformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.31.0->simpletransformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.31.0->simpletransformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.31.0->simpletransformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.31.0->simpletransformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.31.0->simpletransformers) (0.1.2)
# Downloading simpletransformers-0.70.5-py3-none-any.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.8/330.8 kB 18.6 MB/s eta 0:00:00
# Downloading streamlit-1.57.0-py3-none-any.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 78.4 MB/s eta 0:00:00
# Downloading tensorboardx-2.6.5-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 8.8 MB/s eta 0:00:00
# Downloading pydeck-0.9.2-py2.py3-none-any.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 134.7 MB/s eta 0:00:00
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=53be86d4e07e0079714c80c1fbf0afdbe40fdca77a47a52a19a2ef998f5467b9
#   Stored in directory: /root/.cache/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# Installing collected packages: tensorboardx, pydeck, seqeval, streamlit, simpletransformers
# Successfully installed pydeck-0.9.2 seqeval-1.2.2 simpletransformers-0.70.5 streamlit-1.57.0 tensorboardx-2.6.5

# %%
# !pip install transformers==4.57.6
# !pip install simpletransformers==0.70.5
# Out:
# Requirement already satisfied: transformers==4.57.6 in /usr/local/lib/python3.12/dist-packages (4.57.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (3.29.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.6) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.6) (1.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.6) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.6) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.6) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.6) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.6) (2026.4.22)
# Requirement already satisfied: simpletransformers==0.70.5 in /usr/local/lib/python3.12/dist-packages (0.70.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (2.32.4)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (2025.11.3)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (4.57.6)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (4.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (1.6.1)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (1.2.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (2.20.0)
# Requirement already satisfied: tensorboardx in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (2.6.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (2.2.2)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (0.22.2)
# Requirement already satisfied: wandb>=0.10.32 in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (0.26.1)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (1.57.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from simpletransformers==0.70.5) (0.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers>=4.31.0->simpletransformers==0.70.5) (3.29.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.31.0->simpletransformers==0.70.5) (0.36.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.31.0->simpletransformers==0.70.5) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.31.0->simpletransformers==0.70.5) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.31.0->simpletransformers==0.70.5) (0.7.0)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers==0.70.5) (8.3.3)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers==0.70.5) (3.1.47)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers==0.70.5) (4.9.6)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers==0.70.5) (5.29.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers==0.70.5) (2.12.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers==0.70.5) (2.58.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.10.32->simpletransformers==0.70.5) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->simpletransformers==0.70.5) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->simpletransformers==0.70.5) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->simpletransformers==0.70.5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->simpletransformers==0.70.5) (2026.4.22)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->simpletransformers==0.70.5) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->simpletransformers==0.70.5) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->simpletransformers==0.70.5) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->simpletransformers==0.70.5) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (2025.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->simpletransformers==0.70.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->simpletransformers==0.70.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->simpletransformers==0.70.5) (2026.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->simpletransformers==0.70.5) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->simpletransformers==0.70.5) (3.6.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (6.2.6)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (11.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (0.9.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (0.10.2)
# Requirement already satisfied: starlette>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (0.52.1)
# Requirement already satisfied: uvicorn>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (0.46.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (0.7.1)
# Requirement already satisfied: anyio>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (4.13.0)
# Requirement already satisfied: python-multipart>=0.0.10 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (0.0.26)
# Requirement already satisfied: websockets>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (15.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit->simpletransformers==0.70.5) (6.0.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->simpletransformers==0.70.5) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->simpletransformers==0.70.5) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->simpletransformers==0.70.5) (3.10.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->simpletransformers==0.70.5) (75.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->simpletransformers==0.70.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->simpletransformers==0.70.5) (3.1.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers==0.70.5) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers==0.70.5) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers==0.70.5) (2.20.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (3.13.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers==0.70.5) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.31.0->simpletransformers==0.70.5) (1.4.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.10.32->simpletransformers==0.70.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.10.32->simpletransformers==0.70.5) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.10.32->simpletransformers==0.70.5) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->simpletransformers==0.70.5) (1.17.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.30.0->streamlit->simpletransformers==0.70.5) (0.16.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers==0.70.5) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (1.23.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers==0.70.5) (5.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers==0.70.5) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers==0.70.5) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers==0.70.5) (0.30.0)

# %%
# Import libraries
import pandas as pd
import numpy as np
import sklearn
from sklearn.metrics import classification_report
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# Import [the 20 newsgroups text dataset](https://scikit-learn.org/0.19/datasets/twenty_newsgroups.html).
#
# The dataset contains around 18,000 newsgroups posts on 20 topics.

# %%
from sklearn.datasets import fetch_20newsgroups

# load only a sub-selection of the categories (4 in our case)
categories = ['alt.atheism', 'comp.graphics', 'sci.med', 'sci.space']

# remove the headers, footers and quotes (to avoid overfitting)
newsgroups_train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'), categories=categories, random_state=42)
newsgroups_test = fetch_20newsgroups(subset='test', remove=('headers', 'footers', 'quotes'), categories=categories, random_state=42)

# %% [markdown]
# ### Data exploration

# %% [markdown]
# The target attribute is the integer index of the category:

# %%
from collections import Counter
Counter(newsgroups_train.target)
# Out:
# Counter({np.int64(3): 593,
#          np.int64(1): 584,
#          np.int64(2): 594,
#          np.int64(0): 480})

# %%
Counter(newsgroups_test.target)
# Out:
# Counter({np.int64(1): 389,
#          np.int64(2): 396,
#          np.int64(0): 319,
#          np.int64(3): 394})

# %% [markdown]
# Convert data to pandas dataframe

# %%
train = pd.DataFrame({'text': newsgroups_train.data, 'labels': newsgroups_train.target})

# %%
print(len(train))
train.head(5)
# Out:
# 2251
#                                                 text  labels
# 0  WHile we are on the subject of the shuttle sof...       3
# 1  There is a program called Graphic Workshop you...       1
# 2                                                          2
# 3  My girlfriend is in pain from kidney stones. S...       2
# 4  I think that's the correct spelling..\n\tI am ...       2

# %%
test = pd.DataFrame({'text': newsgroups_test.data, 'labels': newsgroups_test.target})

# %%
print(len(test))
test.head(5)
# Out:
# 1498
#                                                 text  labels
# 0  \nAnd guess who's here in your place.\n\nPleas...       1
# 1  Does anyone know if any of Currier and Ives et...       1
# 2  =FLAME ON\n=\n=Reading through the posts about...       2
# 3  \nBut in this case I said I hoped that BCCI wa...       0
# 4  \nIn the kind I have made I used a Lite sour c...       2

# %% [markdown]
# Use a subset (10%) of the training set as a development set

# %%
from sklearn.model_selection import train_test_split

train, dev = train_test_split(train, test_size=0.1, random_state=0,
                               stratify=train[['labels']])

# %%
print(len(train))
print("train:", train[['labels']].value_counts(sort=False))
train.head(3)
# Out:
# 2025
# train: labels
# 0         432
# 1         525
# 2         534
# 3         534
# Name: count, dtype: int64
#                                                    text  labels
# 559   I wonder how many atheists out there care to s...       0
# 2060  We are interested in purchasing a grayscale pr...       1
# 1206  Dear Binary Newsers,\n\nI am looking for Quick...       1

# %%
print(len(dev))
print("dev:", dev[['labels']].value_counts(sort=False))
dev.head(3)
# Out:
# 226
# dev: labels
# 0         48
# 1         59
# 2         60
# 3         59
# Name: count, dtype: int64
#                                                    text  labels
# 1570  I'd dump him.  Rude is rude and it seems he en...       2
# 1761  Hi Everyone ::\n\nI am  looking for  some soft...       1
# 455   A friend of mine has been diagnosed with Psori...       2

# %% [markdown]
# ## BERT

# %% [markdown]
# Define model's configuration

# %%
# Model configuration # https://simpletransformers.ai/docs/usage/#configuring-a-simple-transformers-model
model_args = ClassificationArgs()

model_args.overwrite_output_dir=True # overwrite existing saved models in the same directory
model_args.evaluate_during_training=True # to perform evaluation while training the model
# (eval data should be passed to the training method)

model_args.num_train_epochs=10 # number of epochs
model_args.train_batch_size=32 # batch size
model_args.learning_rate=4e-6 # learning rate
model_args.max_seq_length=256 # maximum sequence length
# Note! Increasing max_seq_len may provide better performance, but training time will increase.
# For educational purposes, we set max_seq_len to 256.

# Early stopping to combat overfitting: https://simpletransformers.ai/docs/tips-and-tricks/#using-early-stopping
model_args.use_early_stopping=True
model_args.early_stopping_delta=0.01 # "The improvement over best_eval_loss necessary to count as a better checkpoint"
model_args.early_stopping_metric='eval_loss'
model_args.early_stopping_metric_minimize=True
model_args.early_stopping_patience=2
model_args.evaluate_during_training_steps=32 # how often you want to run validation in terms of training steps (or batches)

# %% [markdown]
# With this configuration, the training will terminate if the eval_loss on the evaluation data does not improve upon the best eval_loss by at least 0.01 for 2 consecutive evaluations.
#
# An evaluation will occur once for every 32 training steps.

# %%
# Checking steps per epoch
steps_per_epoch = int(np.ceil(len(train) / float(model_args.train_batch_size)))
print('Each epoch will have {:,} steps.'.format(steps_per_epoch)) # 64 steps = validating 2 times per epoch
# Out:
# Each epoch will have 64 steps.

# %% [markdown]
# Load the pre-trained model: model_type = bert; model_name = [bert-base-cased](https://huggingface.co/bert-base-cased) (specifies the exact architecture and trained weights to use)

# %%
model = ClassificationModel('bert', 'bert-base-cased', num_labels=4, args=model_args, use_cuda=True) # CUDA is enabled
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
print(str(model.args).replace(',', '\n')) # model args
# Out:
# ClassificationArgs(adafactor_beta1=None
#  adafactor_clip_threshold=1.0
#  adafactor_decay_rate=-0.8
#  adafactor_eps=(1e-30
#  0.001)
#  adafactor_relative_step=True
#  adafactor_scale_parameter=True
#  adafactor_warmup_init=True
#  adam_betas=(0.9
#  0.999)
#  adam_epsilon=1e-08
#  best_model_dir='outputs/best_model'
#  cache_dir='cache_dir/'
#  config={}
#  cosine_schedule_num_cycles=0.5
#  custom_layer_parameters=[]
#  custom_parameter_groups=[]
#  dataloader_num_workers=0
#  dataset_cache_dir=None
#  do_lower_case=False
#  dynamic_quantize=False
#  early_stopping_consider_epochs=False
#  early_stopping_delta=0.01
#  early_stopping_metric='eval_loss'
#  early_stopping_metric_minimize=True
#  early_stopping_patience=2
#  encoding=None
#  eval_batch_size=100
#  evaluate_during_training=True
#  evaluate_during_training_silent=True
#  evaluate_during_training_steps=32
#  evaluate_during_training_verbose=False
#  evaluate_each_epoch=True
#  fp16=True
#  gradient_accumulation_steps=1
#  learning_rate=4e-06
#  local_rank=-1
#  logging_steps=50
#  loss_type=None
#  loss_args={}
#  manual_seed=None
#  max_grad_norm=1.0
#  max_seq_length=256
#  model_name='bert-base-cased'
#  model_type='bert'
#  multiprocessing_chunksize=-1
#  n_gpu=1
#  no_cache=False
#  no_save=False
#  not_saved_args=[]
#  num_train_epochs=10
#  optimizer='AdamW'
#  output_dir='outputs/'
#  overwrite_output_dir=True
#  polynomial_decay_schedule_lr_end=1e-07
#  polynomial_decay_schedule_power=1.0
#  process_count=1
#  quantized_model=False
#  reprocess_input_data=True
#  save_best_model=True
#  save_eval_checkpoints=True
#  save_model_every_epoch=True
#  save_optimizer_and_scheduler=True
#  save_steps=2000
#  scheduler='linear_schedule_with_warmup'
#  silent=False
#  skip_special_tokens=True
#  tensorboard_dir=None
#  thread_count=None
#  tokenizer_name='bert-base-cased'
#  tokenizer_type=None
#  train_batch_size=32
#  train_custom_parameters_only=False
#  trust_remote_code=False
#  use_cached_eval_features=False
#  use_early_stopping=True
#  use_hf_datasets=False
#  use_multiprocessing=True
#  use_multiprocessing_for_evaluation=True
#  wandb_kwargs={}
#  wandb_project=None
#  warmup_ratio=0.06
#  warmup_steps=0
#  weight_decay=0.0
#  model_class='ClassificationModel'
#  as_reranker=False
#  batch_chunk_size=None
#  labels_list=[0
#  1
#  2
#  3]
#  labels_map={}
#  lazy_delimiter='\t'
#  lazy_labels_column=1
#  lazy_loading=False
#  lazy_loading_start_line=1
#  lazy_text_a_column=None
#  lazy_text_b_column=None
#  lazy_text_column=0
#  onnx=False
#  pairwise_reranking_format='repeat_query'
#  regression=False
#  sliding_window=False
#  special_tokens_list=[]
#  stride=0.8
#  tie_value=1
#  tourney_mode=False)

# %% [markdown]
# Fine-tuning the model (takes a while)

# %%
_, history = model.train_model(train, eval_df=dev)
# Out:
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:544: UserWarning: The 'eval_df' parameter has been deprecated and will be removed in a future version. Please use 'eval_data' instead.
#   warnings.warn(
#   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:924: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler()
# Running Epoch 1 of 10:   0%|          | 0/64 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_10712/861421136.py in <cell line: 0>()
# ----> 1 _, history = model.train_model(train, eval_df=dev)
#
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py in train_model(self, train_df, multi_label, output_dir, show_running_loss, args, eval_data, qrels, run_dict, eval_name, eval_set, top_k, include_titles, verbose, **kwargs)
#     660         os.makedirs(output_dir, exist_ok=True)
#     661
# --> 662         global_step, training_details = self.train(
#     663             train_dataloader,
#     664             output_dir,
#
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py in train(self, train_dataloader, output_dir, multi_label, show_running_loss, eval_data, qrels, run_dict, eval_name, eval_set, top_k, include_titles, test_df, verbose, **kwargs)
#    1056
#    1057                         if args.save_eval_checkpoints:
# -> 1058                             self.save_model(
#    1059                                 output_dir_current,
#    1060                                 optimizer,
#
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py in save_model(self, output_dir, optimizer, scheduler, model, results)
#    3140             # Take care of distributed/parallel training
#    3141             model_to_save = model.module if hasattr(model, "module") else model
# -> 3142             model_to_save.save_pretrained(output_dir)
#    3143             self.tokenizer.save_pretrained(output_dir)
#    3144             torch.save(self.args, os.path.join(output_dir, "training_args.bin"))
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py in save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, token, save_peft_format, **kwargs)
#    4171                 # At some point we will need to deal better with save_function (used for TPU and other distributed
#    4172                 # joyfulness), but for now this enough.
# -> 4173                 safe_save_file(shard, os.path.join(save_directory, shard_file), metadata=metadata)
#    4174             else:
#    4175                 save_function(shard, os.path.join(save_directory, shard_file))
#
# /usr/local/lib/python3.12/dist-packages/safetensors/torch.py in save_file(tensors, filename, metadata)
#     305     ```
#     306     """
# --> 307     serialize_file(_flatten(tensors), filename, metadata=metadata)
#     308
#     309
#
# KeyboardInterrupt:

# %%
# Training and evaluation loss
train_loss = history['train_loss']
eval_loss = history['eval_loss']
plt.plot(train_loss, label='Training loss')
plt.plot(eval_loss, label='Evaluation loss')
plt.title('Training and evaluation loss')
plt.legend()

# %% [markdown]
# * Loss measures the “goodness” of your model
#
# * The smaller the loss, the better the classifier is at modeling the relationship between the input data and the output targets
#
# * But you need to be careful not to overfit

# %% [markdown]
# In our case, we stopped training because eval_loss loss did not improve upon the best eval_loss by at least 0.01 for 2 consecutive evaluations.
#
# We can observe fluctuations in the training loss, but overall it is decreasing.
# We can have a smoother learning curve by varying hyperparameters, e.g., learning rate, batch size.

# %%
# Evaluate the model
result, model_outputs, wrong_predictions = model.eval_model(dev)
result
# Out:
# 0it [00:00, ?it/s]
# Running Evaluation:   0%|          | 0/3 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# {'mcc': np.float64(0.8535845258548), 'eval_loss': 0.3493853509426117}

# %% [markdown]
# * mcc: [ Matthews correlation coefficient](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.matthews_corrcoef.html)
#
# * eval_loss: Cross Entropy Loss for dev

# %% [markdown]
# Make predictions with the model (predict the labels of the documents in the test set)

# %%
predicted, probabilities = model.predict(test.text.to_list())
test['predicted'] = predicted
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# Predicting:   0%|          | 0/15 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:2260: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():

# %% [markdown]
# Test set predictions

# %%
test.head(5)
# Out:
#                                                 text  labels  predicted
# 0  \nAnd guess who's here in your place.\n\nPleas...       1          3
# 1  Does anyone know if any of Currier and Ives et...       1          1
# 2  =FLAME ON\n=\n=Reading through the posts about...       2          2
# 3  \nBut in this case I said I hoped that BCCI wa...       0          0
# 4  \nIn the kind I have made I used a Lite sour c...       2          2

# %% [markdown]
# Evaluate the model's performance on the test set

# %%
# Result (note: your result can be different due to randomness in operations)
print(classification_report(test['labels'], test['predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       319
#            1       0.90      0.90      0.90       389
#            2       0.85      0.91      0.88       396
#            3       0.84      0.83      0.84       394
#
#     accuracy                           0.86      1498
#    macro avg       0.86      0.86      0.86      1498
# weighted avg       0.86      0.86      0.86      1498

# %% [markdown]
# ### End of this notebook.
