# %% [markdown]
# ## Lab6-Assignment: Topic Classification

# %% [markdown]
# Use the same training, development, and test partitions of the the 20 newsgroups text dataset as in Lab6.4-Topic-classification-BERT.ipynb

# %% [markdown]
# * Fine-tune and examine the performance of another transformer-based pretrained language models, e.g., RoBERTa, XLNet
#
# * Compare the performance of this model to the results achieved in Lab6.4-Topic-classification-BERT.ipynb and to a conventional machine learning approach (e.g., SVM, Naive Bayes) using bag-of-words or other engineered features of your choice.
# Describe the differences in performance in terms of Precision, Recall, and F1-score evaluation metrics.

# %%
# !pip install transformers==4.57.6
# !pip install simpletransformers==0.70.5
# Out:
# Collecting transformers==4.57.6
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.57.6) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers==4.57.6)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.57.6) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.57.6) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.57.6) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.57.6) (2024.9.11)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.57.6) (2.32.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers==4.57.6)
#   Downloading tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting safetensors>=0.4.3 (from transformers==4.57.6)
#   Downloading safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/lib/python3.12/site-packages (from transformers==4.57.6) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.6) (2024.6.1)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.6)
#   Downloading hf_xet-1.5.0-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.6) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers==4.57.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers==4.57.6) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers==4.57.6) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers==4.57.6) (2026.1.4)
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 17.3 MB/s eta 0:00:00MB/s eta 0:00:01:01
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 11.4 MB/s eta 0:00:00
# Downloading safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# Downloading tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 23.5 MB/s eta 0:00:00
# Downloading hf_xet-1.5.0-cp37-abi3-macosx_11_0_arm64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 18.6 MB/s eta 0:00:00
# Installing collected packages: safetensors, hf-xet, huggingface-hub, tokenizers, transformers
# Successfully installed hf-xet-1.5.0 huggingface-hub-0.36.2 safetensors-0.7.0 tokenizers-0.22.2 transformers-4.57.6
# Collecting simpletransformers==0.70.5
#   Downloading simpletransformers-0.70.5-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from simpletransformers==0.70.5) (1.26.4)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from simpletransformers==0.70.5) (2.32.3)
# Requirement already satisfied: tqdm>=4.47.0 in /opt/anaconda3/lib/python3.12/site-packages (from simpletransformers==0.70.5) (4.66.5)
# Requirement already satisfied: regex in /opt/anaconda3/lib/python3.12/site-packages (from simpletransformers==0.70.5) (2024.9.11)
# Requirement already satisfied: transformers>=4.31.0 in /opt/anaconda3/lib/python3.12/site-packages (from simpletransformers==0.70.5) (4.57.6)
# Collecting datasets (from simpletransformers==0.70.5)
#   Downloading datasets-4.8.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from simpletransformers==0.70.5) (1.13.1)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.12/site-packages (from simpletransformers==0.70.5) (1.5.1)
# Collecting seqeval (from simpletransformers==0.70.5)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tensorboard (from simpletransformers==0.70.5)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorboardx (from simpletransformers==0.70.5)
#   Downloading tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (from simpletransformers==0.70.5) (2.2.2)
# Requirement already satisfied: tokenizers in /opt/anaconda3/lib/python3.12/site-packages (from simpletransformers==0.70.5) (0.22.2)
# Collecting wandb>=0.10.32 (from simpletransformers==0.70.5)
#   Downloading wandb-0.27.0-py3-none-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: streamlit in /opt/anaconda3/lib/python3.12/site-packages (from simpletransformers==0.70.5) (1.52.2)
# Collecting sentencepiece (from simpletransformers==0.70.5)
#   Downloading sentencepiece-0.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (10 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.31.0->simpletransformers==0.70.5) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.31.0->simpletransformers==0.70.5) (0.36.2)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.31.0->simpletransformers==0.70.5) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.31.0->simpletransformers==0.70.5) (6.0.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from transformers>=4.31.0->simpletransformers==0.70.5) (0.7.0)
# Collecting click>=8.2.0 (from wandb>=0.10.32->simpletransformers==0.70.5)
#   Downloading click-8.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.10.32->simpletransformers==0.70.5) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.10.32->simpletransformers==0.70.5) (3.10.0)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.10.32->simpletransformers==0.70.5) (5.29.3)
# Requirement already satisfied: pydantic<3,>=2.6 in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.10.32->simpletransformers==0.70.5) (2.12.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.10.32->simpletransformers==0.70.5) (2.18.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /opt/anaconda3/lib/python3.12/site-packages (from wandb>=0.10.32->simpletransformers==0.70.5) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->simpletransformers==0.70.5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->simpletransformers==0.70.5) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->simpletransformers==0.70.5) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->simpletransformers==0.70.5) (2026.1.4)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets->simpletransformers==0.70.5) (21.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets->simpletransformers==0.70.5) (0.3.8)
# Requirement already satisfied: httpx<1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets->simpletransformers==0.70.5) (0.27.0)
# Collecting xxhash (from datasets->simpletransformers==0.70.5)
#   Downloading xxhash-3.7.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.20 (from datasets->simpletransformers==0.70.5)
#   Downloading multiprocess-0.70.19-py312-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (2024.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->simpletransformers==0.70.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->simpletransformers==0.70.5) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->simpletransformers==0.70.5) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->simpletransformers==0.70.5) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->simpletransformers==0.70.5) (3.5.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit->simpletransformers==0.70.5) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit->simpletransformers==0.70.5) (1.6.2)
# Requirement already satisfied: cachetools<7,>=4.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit->simpletransformers==0.70.5) (5.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit->simpletransformers==0.70.5) (12.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit->simpletransformers==0.70.5) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit->simpletransformers==0.70.5) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit->simpletransformers==0.70.5) (6.4.1)
# Collecting absl-py>=0.4 (from tensorboard->simpletransformers==0.70.5)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard->simpletransformers==0.70.5)
#   Using cached grpcio-1.80.0-cp312-cp312-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard->simpletransformers==0.70.5) (3.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard->simpletransformers==0.70.5) (75.1.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->simpletransformers==0.70.5)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard->simpletransformers==0.70.5) (3.0.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers==0.70.5) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/lib/python3.12/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers==0.70.5) (4.23.0)
# Requirement already satisfied: toolz in /opt/anaconda3/lib/python3.12/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers==0.70.5) (0.12.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (3.10.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers==0.70.5) (4.0.7)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1.0.0->datasets->simpletransformers==0.70.5) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1.0.0->datasets->simpletransformers==0.70.5) (1.0.2)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1.0.0->datasets->simpletransformers==0.70.5) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets->simpletransformers==0.70.5) (0.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.31.0->simpletransformers==0.70.5) (1.5.0)
# Collecting dill<0.4.2,>=0.3.0 (from datasets->simpletransformers==0.70.5)
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb>=0.10.32->simpletransformers==0.70.5) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb>=0.10.32->simpletransformers==0.70.5) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb>=0.10.32->simpletransformers==0.70.5) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->simpletransformers==0.70.5) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers==0.70.5) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->simpletransformers==0.70.5) (1.11.0)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers==0.70.5) (4.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers==0.70.5) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers==0.70.5) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->simpletransformers==0.70.5) (0.10.6)
# Downloading simpletransformers-0.70.5-py3-none-any.whl (330 kB)
# Downloading wandb-0.27.0-py3-none-macosx_12_0_arm64.whl (24.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 24.6 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading datasets-4.8.5-py3-none-any.whl (528 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 11.3 MB/s eta 0:00:00
# Downloading sentencepiece-0.2.1-cp312-cp312-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.1 MB/s eta 0:00:00
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 25.7 MB/s eta 0:00:0031m27.7 MB/s eta 0:00:01
# Downloading tensorboardx-2.6.5-py3-none-any.whl (87 kB)
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading click-8.4.0-py3-none-any.whl (116 kB)
# Using cached grpcio-1.80.0-cp312-cp312-macosx_11_0_universal2.whl (12.0 MB)
# Downloading multiprocess-0.70.19-py312-none-any.whl (150 kB)
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading xxhash-3.7.0-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=33d16d30324a18eb7390d55f6c6fe8e0a92467020f9e5bfa3daf9b7ab80a3685
#   Stored in directory: /Users/evelina/Library/Caches/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# Installing collected packages: xxhash, tensorboardx, tensorboard-data-server, sentencepiece, grpcio, dill, click, absl-py, tensorboard, multiprocess, wandb, seqeval, datasets, simpletransformers
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.8
#     Uninstalling dill-0.3.8:
#       Successfully uninstalled dill-0.3.8
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
# Successfully installed absl-py-2.4.0 click-8.4.0 datasets-4.8.5 dill-0.4.1 grpcio-1.80.0 multiprocess-0.70.19 sentencepiece-0.2.1 seqeval-1.2.2 simpletransformers-0.70.5 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorboardx-2.6.5 wandb-0.27.0 xxhash-3.7.0

# %%
# Import libraries
import pandas as pd
import numpy as np
import sklearn
from sklearn.metrics import classification_report
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import matplotlib.pyplot as plt
import seaborn as sn

# %%
from sklearn.datasets import fetch_20newsgroups

# load only a sub-selection of the categories (4 in our case)
categories = ['alt.atheism', 'comp.graphics', 'sci.med', 'sci.space']

# remove the headers, footers and quotes (to avoid overfitting)
newsgroups_train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'), categories=categories, random_state=42)
newsgroups_test = fetch_20newsgroups(subset='test', remove=('headers', 'footers', 'quotes'), categories=categories, random_state=42)

# %%
from collections import Counter
Counter(newsgroups_train.target)
# Out:
# Counter({2: 594, 3: 593, 1: 584, 0: 480})

# %%
Counter(newsgroups_test.target)
# Out:
# Counter({2: 396, 3: 394, 1: 389, 0: 319})

# %%
train = pd.DataFrame({'text': newsgroups_train.data, 'labels': newsgroups_train.target})

# %%
print(len(train))
train.head(5)
# Out:
# 2251
#                                                 text  labels
# 0  WHile we are on the subject of the shuttle sof...       3
# 1  There is a program called Graphic Workshop you...       1
# 2                                                          2
# 3  My girlfriend is in pain from kidney stones. S...       2
# 4  I think that's the correct spelling..\n\tI am ...       2

# %%
test = pd.DataFrame({'text': newsgroups_test.data, 'labels': newsgroups_test.target})

# %%
print(len(test))
test.head(5)
# Out:
# 1498
#                                                 text  labels
# 0  \nAnd guess who's here in your place.\n\nPleas...       1
# 1  Does anyone know if any of Currier and Ives et...       1
# 2  =FLAME ON\n=\n=Reading through the posts about...       2
# 3  \nBut in this case I said I hoped that BCCI wa...       0
# 4  \nIn the kind I have made I used a Lite sour c...       2

# %%
from sklearn.model_selection import train_test_split

train, dev = train_test_split(train, test_size=0.1, random_state=0,
                               stratify=train[['labels']])

# %%
print(len(train))
print("train:", train[['labels']].value_counts(sort=False))
train.head(3)
# Out:
# 2025
# train: labels
# 0         432
# 1         525
# 2         534
# 3         534
# Name: count, dtype: int64
#                                                    text  labels
# 559   I wonder how many atheists out there care to s...       0
# 2060  We are interested in purchasing a grayscale pr...       1
# 1206  Dear Binary Newsers,\n\nI am looking for Quick...       1

# %%
print(len(dev))
print("dev:", dev[['labels']].value_counts(sort=False))
dev.head(3)
# Out:
# 226
# dev: labels
# 0         48
# 1         59
# 2         60
# 3         59
# Name: count, dtype: int64
#                                                    text  labels
# 1570  I'd dump him.  Rude is rude and it seems he en...       2
# 1761  Hi Everyone ::\n\nI am  looking for  some soft...       1
# 455   A friend of mine has been diagnosed with Psori...       2

# %%
# Model configuration # https://simpletransformers.ai/docs/usage/#configuring-a-simple-transformers-model
model_args = ClassificationArgs()

model_args.overwrite_output_dir=True # overwrite existing saved models in the same directory
model_args.evaluate_during_training=True # to perform evaluation while training the model
# (eval data should be passed to the training method)

model_args.num_train_epochs=10 # number of epochs
model_args.train_batch_size=32 # batch size
model_args.learning_rate=4e-6 # learning rate
model_args.max_seq_length=256 # maximum sequence length
# Note! Increasing max_seq_len may provide better performance, but training time will increase.
# For educational purposes, we set max_seq_len to 256.

# Early stopping to combat overfitting: https://simpletransformers.ai/docs/tips-and-tricks/#using-early-stopping
model_args.use_early_stopping=True
model_args.early_stopping_delta=0.01 # "The improvement over best_eval_loss necessary to count as a better checkpoint"
model_args.early_stopping_metric='eval_loss'
model_args.early_stopping_metric_minimize=True
model_args.early_stopping_patience=2
model_args.evaluate_during_training_steps=32 # how often you want to run validation in terms of training steps (or batches)

# %%
# Checking steps per epoch
steps_per_epoch = int(np.ceil(len(train) / float(model_args.train_batch_size)))
print('Each epoch will have {:,} steps.'.format(steps_per_epoch)) # 64 steps = validating 2 times per epoch
# Out:
# Each epoch will have 64 steps.

# %%
model = ClassificationModel('roberta', 'roberta-base', num_labels=4, args=model_args, use_cuda=True)

# %%
_, history = model.train_model(train, eval_df=dev)
# Out:
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:544: UserWarning: The 'eval_df' parameter has been deprecated and will be removed in a future version. Please use 'eval_data' instead.
#   warnings.warn(
#   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:924: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler()
# Running Epoch 1 of 10:   0%|          | 0/64 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# Running Epoch 2 of 10:   0%|          | 0/64 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# Running Epoch 3 of 10:   0%|          | 0/64 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# Running Epoch 4 of 10:   0%|          | 0/64 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# Running Epoch 5 of 10:   0%|          | 0/64 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# Running Epoch 6 of 10:   0%|          | 0/64 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# Running Epoch 7 of 10:   0%|          | 0/64 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:950: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():

# %%
# Training and evaluation loss
train_loss = history['train_loss']
eval_loss = history['eval_loss']
plt.plot(train_loss, label='Training loss')
plt.plot(eval_loss, label='Evaluation loss')
plt.title('Training and evaluation loss')
plt.legend()

# %%
# Evaluate the model
result, model_outputs, wrong_predictions = model.eval_model(dev)
result
# Out:
# 0it [00:00, ?it/s]
# Running Evaluation:   0%|          | 0/3 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/classification/classification_model.py:1570: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# {'mcc': np.float64(0.8467073706955812), 'eval_loss': 0.2293047954638799}

# %%
predicted, probabilities = model.predict(test.text.to_list())
test['predicted'] = predicted

# %%
test.head(5)
# Out:
#                                                 text  labels  predicted
# 0  \nAnd guess who's here in your place.\n\nPleas...       1          3
# 1  Does anyone know if any of Currier and Ives et...       1          1
# 2  =FLAME ON\n=\n=Reading through the posts about...       2          0
# 3  \nBut in this case I said I hoped that BCCI wa...       0          0
# 4  \nIn the kind I have made I used a Lite sour c...       2          2

# %%
# Result (note: your result can be different due to randomness in operations)
print(classification_report(test['labels'], test['predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82       319
#            1       0.90      0.89      0.89       389
#            2       0.86      0.91      0.88       396
#            3       0.86      0.81      0.83       394
#
#     accuracy                           0.86      1498
#    macro avg       0.86      0.86      0.86      1498
# weighted avg       0.86      0.86      0.86      1498

# %%
print(test.columns)
# Out:
# Index(['text', 'labels'], dtype='object')

# %% [markdown]
# # Conventional machine learning baseline: TF-IDF + SVM

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report

svm_clf = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english', max_features=10000)),
    ('clf', LinearSVC())
])

svm_clf.fit(train['text'], train['labels'])

svm_predicted = svm_clf.predict(test['text'])

print(classification_report(
    test['labels'],
    svm_predicted,
    target_names=newsgroups_train.target_names
))
# Out:
#                precision    recall  f1-score   support
#
#   alt.atheism       0.84      0.76      0.80       319
# comp.graphics       0.88      0.89      0.88       389
#       sci.med       0.88      0.83      0.85       396
#     sci.space       0.78      0.86      0.82       394
#
#      accuracy                           0.84      1498
#     macro avg       0.84      0.84      0.84      1498
#  weighted avg       0.84      0.84      0.84      1498

# %% [markdown]
# * Compare the performance of this model to the results achieved in Lab6.4-Topic-classification-BERT.ipynb and to a conventional machine learning approach (e.g., SVM, Naive Bayes) using bag-of-words or other engineered features of your choice.
# Describe the differences in performance in terms of Precision, Recall, and F1-score evaluation metrics.

# %% [markdown]
# ## Comparison of RoBERTa, BERT, and SVM
#
# RoBERTa model achieved an accuracy of 0.86, with both macro and weighted F1-scores equal to 0.86. Its best results were on `comp.graphics` and `sci.med`, with F1-scores of 0.89 and 0.88.
#
# BERT model from Lab6.4 performed slightly better overall, with an accuracy and macro F1-score of 0.87. It achieved the highest F1-score on `comp.graphics` (0.91) and also performed very well on `sci.med` (0.90).
# RoBERTa and BERT result difference is relatively small, so both transformer-based models are effective for text classification.
#
# SVM classifier achieved an accuracy and macro F1-score of 0.84. This is slightly lower than both transformer models. SVM still performed well on categories with distinctive vocabulary, such as `comp.graphics`, but overall it had lower recall and F1-scores.
# For example, SVM `alt.atheism` recall was 0.76 compared to 0.82 for both RoBERTa and BERT. Transformer-based models have an advantage because they use contextual embeddings, while SVM mainly relies on word-frequency information from TF-IDF features.
